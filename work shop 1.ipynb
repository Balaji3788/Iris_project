# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as svs
import cv2
# Out:
# C:\Users\STUDENT\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
# !pip install opencv-python

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as img
from sklearn.model_selection import train_test_split
import seaborn as svs
import cv2

# %%
ms=cv2.imread("Downloads/ice-age-3-dawn-of-the-dinosaurs-wallpaper-preview.jpg")

# %%
print(ms)
# Out:
# [[[173 231 253]
#   [170 228 250]
#   [162 225 246]
#   ...
#   [ 34  32  32]
#   [ 34  32  32]
#   [ 34  32  32]]
#
#  [[174 231 255]
#   [171 228 253]
#   [163 225 249]
#   ...
#   [ 34  32  32]
#   [ 34  32  32]
#   [ 34  32  32]]
#
#  [[174 231 255]
#   [171 228 253]
#   [164 226 250]
#   ...
#   [ 34  32  32]
#   [ 34  32  32]
#   [ 34  32  32]]
#
#  ...
#
#  [[ 40 109  89]
#   [ 38 104  85]
#   [ 37 102  81]
#   ...
#   [ 69 127 176]
#   [ 70 128 177]
#   [ 70 128 177]]
#
#  [[ 39 104  78]
#   [ 39 103  74]
#   [ 36 100  70]
#   ...
#   [ 67 122 167]
#   [ 69 124 169]
#   [ 71 126 171]]
#
#  [[ 29  94  68]
#   [ 28  92  63]
#   [ 27  89  59]
#   ...
#   [ 67 122 167]
#   [ 69 124 169]
#   [ 71 126 171]]]

# %%
cv2.imshow("image",ms)
cv2.waitKey(0)
# Out:
# -1

# %%
import pandas as pd
ms=pd.read_csv("Downloads/Group of animals.csv")

# %%
ms
# Out:
#   label_name  bbox_x  bbox_y  bbox_width  bbox_height  \
# 0    rangoon     522     182         149          268
# 1    mammoth     196       0         325          450
# 2    ginibic     144      56          59           90
# 3      tiger      17     249         185          201
#
#                                           image_name  image_width  \
# 0  ice-age-3-dawn-of-the-dinosaurs-wallpaper-prev...          728
# 1  ice-age-3-dawn-of-the-dinosaurs-wallpaper-prev...          728
# 2  ice-age-3-dawn-of-the-dinosaurs-wallpaper-prev...          728
# 3  ice-age-3-dawn-of-the-dinosaurs-wallpaper-prev...          728
#
#    image_height
# 0           450
# 1           450
# 2           450
# 3           450

# %%
ms.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   label_name    4 non-null      object
#  1   bbox_x        4 non-null      int64
#  2   bbox_y        4 non-null      int64
#  3   bbox_width    4 non-null      int64
#  4   bbox_height   4 non-null      int64
#  5   image_name    4 non-null      object
#  6   image_width   4 non-null      int64
#  7   image_height  4 non-null      int64
# dtypes: int64(6), object(2)
# memory usage: 384.0+ bytes

# %%
ms.sum()
# Out:
# label_name                             rangoonmammothginibictiger
# bbox_x                                                        879
# bbox_y                                                        487
# bbox_width                                                    718
# bbox_height                                                  1009
# image_name      ice-age-3-dawn-of-the-dinosaurs-wallpaper-prev...
# image_width                                                  2912
# image_height                                                 1800
# dtype: object

# %%
ms.isnull().sum()
# Out:
# label_name      0
# bbox_x          0
# bbox_y          0
# bbox_width      0
# bbox_height     0
# image_name      0
# image_width     0
# image_height    0
# dtype: int64

# %%
ms
# Out:
#   label_name  bbox_x  bbox_y  bbox_width  bbox_height  \
# 0    rangoon     522     182         149          268
# 1    mammoth     196       0         325          450
# 2    ginibic     144      56          59           90
# 3      tiger      17     249         185          201
#
#                                           image_name  image_width  \
# 0  ice-age-3-dawn-of-the-dinosaurs-wallpaper-prev...          728
# 1  ice-age-3-dawn-of-the-dinosaurs-wallpaper-prev...          728
# 2  ice-age-3-dawn-of-the-dinosaurs-wallpaper-prev...          728
# 3  ice-age-3-dawn-of-the-dinosaurs-wallpaper-prev...          728
#
#    image_height
# 0           450
# 1           450
# 2           450
# 3           450

# %%
svs.pairplot(ms)

# %%
k = svs.boxplot(data=ms)

# %%
svs.scatterplot(data=ms)
# Out:
# <AxesSubplot:>

# %%
svs.displot(data=ms)

# %%
testimg=img.imread("Downloads/ice-age-3-dawn-of-the-dinosaurs-wallpaper-preview.jpg")
plt.imshow(testimg)

# %%
import cv2

# %%
Start_point=(4,4)
End_point=(220,220)
color=(225,0,0)
thickness=9

# %%
testimg=cv2.rectangle(testimg,Start_point,End_point,color,thickness)
plt.imshow(testimg)

# %%
cv2.imshow("name",testimg)
cv2.waitKey(0)
# Out:
# -1

# %%
from sklearn import datasets,linear_model
import pandas as pd
import seaborn,matplotlib,numpy
import linear regression
